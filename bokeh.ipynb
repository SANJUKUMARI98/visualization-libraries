# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bokeh in /usr/local/lib/python3.8/dist-packages (2.4.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.8/dist-packages (from bokeh) (4.5.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from bokeh) (1.22.4)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.8/dist-packages (from bokeh) (8.4.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from bokeh) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.8/dist-packages (from bokeh) (6.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.8/dist-packages (from bokeh) (23.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.8/dist-packages (from bokeh) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=2.9->bokeh) (2.1.2)

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure,output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p= figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="5499acea-4fa8-4020-a18f-f8e31416cc2a" data-root-id="1041"></div>

# %%
output_file('test.html')
p=figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.square(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="7f0ecd52-adc7-402e-bee5-1a5ac0b4ec1c" data-root-id="1327"></div>

# %%
output_file('test.html')
p=figure(title='test flower')
p.xaxis.axis_label='petal_length'
p.yaxis.axis_label='petal_width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="dc6e538f-416e-4189-bbcf-17637afa29da" data-root-id="1589"></div>

# %%
output_file('test.html')
p=figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.square(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="a6f01dfc-b2d5-45ca-90e7-9ac88a169cce" data-root-id="1861"></div>

# %%
output_file('test.html')
p=figure(title='test flower')
p.xaxis.axis_label='petal_length'
p.yaxis.axis_label="petal_width"
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="067e9df3-f332-4cc9-a647-e547ca9d6016" data-root-id="2143"></div>

# %%
output_file("test.html")
p=figure(title='test flower')
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="aa1c9439-63e1-432a-bf0d-5e65b425efcc" data-root-id="2501"></div>

# %%
x=[3,4,5,6,7]
y=[4,5,5,6,7,4]
output_file('line.html')
p=figure(title='line graph')
p.line(x,y)
show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 5), ('y', 6)
#   <div class="bk-root" id="e2b32e20-1edd-4339-8bb0-d14148e78537" data-root-id="2792"></div>

# %%
x=[2,3,4,5,6]
y=[4,5,6,7,8]
output_file('test.html')
p=figure(title='line graph')
p.scatter(x,y)
show(p)
# Out:
#   <div class="bk-root" id="b145d92c-b9ea-44fc-810b-56a428808899" data-root-id="3125"></div>

# %%
x=[2,3,6,6,6,4,5,6]
output_file('test.html')
p=figure(title='line graph')
p.scatter(x,y ,size=19,fill_color='red',legend_label='this is my data point')
show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 8), ('y', 5)
#   <div class="bk-root" id="64427bf5-2430-4ab5-979a-bd5cdd29928e" data-root-id="3501"></div>
